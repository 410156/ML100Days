# %%
import pandas as pd
import numpy as np
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# ...

# %%
#score_df = pd.DataFrame(score_df , index = ['sex' , 'class' , 'student_id'] , columns=['chinese_score','english_score','math_score'])

score_df=score_df.pivot(index =  'sex', columns='chinese_score', values=['class', 'student_id','english_score','math_score'] )
score_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-46c59214915b> in <module>
#       1 #score_df = pd.DataFrame(score_df , index = ['sex' , 'class' , 'student_id'] , columns=['chinese_score','english_score','math_score'])
#       2
# ----> 3 score_df=score_df.pivot(index =  'sex', columns='chinese_score', values=['class', 'student_id','english_score','math_score'] )
#       4 score_df
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     475         else:
# ...
